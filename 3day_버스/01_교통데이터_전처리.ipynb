# %%
import pandas as pd

# %%
### trfcard (0)번 폴더의 trfcard.csv 파일 읽어 들이기
# 함수명 : read_csv()
# 데이터프레임 변수명 : df_bus_card_org

df_bus_card_org = pd.read_csv("./01_data_원본/trfcard (0)/trfcard.csv")
df_bus_card_org
# Out:
#               on_date        off_date route_name                  descr  \
# 0      20200102051049  20200102051844        131         양덕-송도-시청-양학-양덕
# 1      20200102051338  20200102054549        175       문덕-고속터미널-선린병원-달전
# 2      20200102051549  20200102051930        160         문덕-대송-송도-죽도-용흥
# 3      20200102051617  20200102055046        175       문덕-고속터미널-선린병원-달전
# 4      20200102051841  20200102052310        102  문덕-남구청-고속터미널-북구보건소-양덕
# ...               ...             ...        ...                    ...
# 16180  20200102232423  20200102233802        102  문덕-남구청-고속터미널-북구보건소-양덕
# 16181  20200102232449  20200102232657        200        양덕-남구청(야구장)-구룡포
# 16182  20200102232849  20200102233230        500      문덕-시외터미널-흥해-청하-월포
# 16183  20200102233518  20200102235624        107        문덕-시외(고속)터미널-흥해
# 16184  20200102235936  20200103000017        108      양덕-죽도-양학-시청-유강-지곡
#
#       age_type trans_yn addfee_yn start_bstop  start_gps_x  start_gps_y  \
# 0           일반        N         N       양덕차고지   129.401693    36.077258
# 1           일반        N         N       문덕사거리   129.403178    35.962298
# 2           일반        N         N       문덕사거리   129.403442    35.962846
# 3           일반        N         N      부영사랑3차   129.402520    35.973038
# 4           일반        N         N        문덕온천   129.406532    35.961964
# ...        ...      ...       ...         ...          ...          ...
# 16180       일반        Y         N        죽도시장   129.365486    36.034110
# 16181       일반        N         N       형산로터리   129.368470    36.011630
# 16182       일반        N         N       남부경찰서   129.344637    36.005408
# 16183       일반        N         N       쌍용사거리   129.354637    36.015728
# 16184       일반        N         N      장량휴먼시아   129.384057    36.090840
#
#        end_bstop   end_gps_x  end_gps_y
# 0         동부초등학교  129.380866  36.062209
# 1      새마을금고해도지점  129.370626  36.015468
# 2        성우오토모티브  129.384492  35.972675
# 3            오거리  129.366312  36.031816
# 4          용덕사거리  129.415174  35.972826
# ...          ...         ...        ...
# 16180     문화예술회관  129.365551  36.010599
# 16181  뱃머리 평생학습원  129.354538  36.009020
# 16182     연일전통시장  129.349210  35.997120
# 16183      화이트빌라  129.406610  35.957090
# 16184      법원검찰청  129.387075  36.090211
#
# [16185 rows x 13 columns]

# %%
df_bus_card_org.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16185 entries, 0 to 16184
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   on_date      16185 non-null  int64
#  1   off_date     16185 non-null  int64
#  2   route_name   16185 non-null  object
#  3   descr        16185 non-null  object
#  4   age_type     16185 non-null  object
#  5   trans_yn     16185 non-null  object
#  6   addfee_yn    16185 non-null  object
#  7   start_bstop  16185 non-null  object
#  8   start_gps_x  16185 non-null  float64
#  9   start_gps_y  16185 non-null  float64
#  10  end_bstop    16185 non-null  object
#  11  end_gps_x    16185 non-null  float64
#  12  end_gps_y    16185 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 1.6+ MB

# %% [markdown]
# ### 영문 컬럼명 -> 한글컬럼명으로 변환하기

# %%
### 직접 컬럼명을 딕션너리로 만들어서 사용할 경우
"""
{'on_date' : '승차시각',
'off_date' : '하차시각',
'route_name' : '노선명',
'descr' : '노선설명',
'age_type' : '승객연령',
'trans_yn' : '환승여부',
'addfee_yn' : '추가운임여부',
'start_bstop' : '승차정류장',
'start_gps_x' : '승차정류장 GPS X',
'start_gps_y' : '승차정류장 GPS Y',
'end_bstop' : '하차정류장',
'end_gps_x' : '하차정류장 GPS X',
'end_gps_y' : '하차정류장 GPS Y'}
"""
# Out:
# "\n{'on_date' : '승차시각',\n'off_date' : '하차시각',\n'route_name' : '노선명',\n'descr' : '노선설명',\n'age_type' : '승객연령',\n'trans_yn' : '환승여부',\n'addfee_yn' : '추가운임여부',\n'start_bstop' : '승차정류장',\n'start_gps_x' : '승차정류장 GPS X',\n'start_gps_y' : '승차정류장 GPS Y',\n'end_bstop' : '하차정류장',\n'end_gps_x' : '하차정류장 GPS X',\n'end_gps_y' : '하차정류장 GPS Y'}\n"

# %%
### 데이터 정의서에서 "영문 및 한글" 컬럼명만 읽어들이기
# 컬럼명의 위치 : 엑셀기준 3번째 행
# 필요한 데이터의 열 : B, C
# 데이터프레임 변수명 : df_bus_card_col_org
df_bus_card_col_org = pd.read_excel("./01_data_원본/trfcard (0)/trfcard_columns.xlsx",
                         header = 2, 
                         usecols = "B:C")
df_bus_card_col_org
# Out:
#        컬럼명 (영문)     컬럼명 (한글)
# 0       on_date         승차시각
# 1      off_date         하차시각
# 2    route_name          노선명
# 3         descr         노선설명
# 4      age_type         승객연령
# 5      trans_yn         환승여부
# 6     addfee_yn       추가운임여부
# 7   start_bstop        승차정류장
# 8   start_gps_x  승차정류장 GPS X
# 9   start_gps_y  승차정류장 GPS Y
# 10    end_bstop        하차정류장
# 11    end_gps_x  하차정류장 GPS X
# 12    end_gps_y  하차정류장 GPS Y

# %%
### 조회한 영문 및 한글컬럼 데이터를 이용해서
# 딕션너리 데이터로 변환하기
# - key는 영문명, value는 한글명으로
# - 변수명 : df_bus_card_col_new_dict

# 내가 한거.. 에러남... 밑에 강사님하고 한것 있음
eng_list = df_bus_card_col_org["컬럼명 (영문)"].to_list() 
kor_list = df_bus_card_col_org["컬럼명 (한글)"].to_list()
df_bus_card_col_new_dict = pd.merge(eng_list, kor_list)
df_bus_card_col_new_dict

# %%
### 조회한 영문 및 한글컬럼 데이터를 이용해서
# 딕션너리 데이터로 변환하기
# - key는 영문명, value는 한글명으로
# - 변수명 : df_bus_card_col_new_dict

### 딕셔너리 만들기 - 1방식
# for문을 이용하는 방식
df_bus_card_col_new_dict = {}
for k, v in zip(df_bus_card_col_org["컬럼명 (영문)"],
                df_bus_card_col_org["컬럼명 (한글)"]) :
    df_bus_card_col_new_dict[k] = v
    
df_bus_card_col_new_dict
# Out:
# {'on_date': '승차시각',
#  'off_date': '하차시각',
#  'route_name': '노선명',
#  'descr': '노선설명',
#  'age_type': '승객연령',
#  'trans_yn': '환승여부',
#  'addfee_yn': '추가운임여부',
#  'start_bstop': '승차정류장',
#  'start_gps_x': '승차정류장 GPS X',
#  'start_gps_y': '승차정류장 GPS Y',
#  'end_bstop': '하차정류장',
#  'end_gps_x': '하차정류장 GPS X',
#  'end_gps_y': '하차정류장 GPS Y'}

# %%
### 조회한 영문 및 한글컬럼 데이터를 이용해서
# 딕션너리 데이터로 변환하기
# - key는 영문명, value는 한글명으로
# - 변수명 : df_bus_card_col_new_dict

### 딕셔너리 만들기 - 2방식
# dic를 이용하는 방식
df_bus_card_col_new_dict = dict(zip(df_bus_card_col_org["컬럼명 (영문)"],
                df_bus_card_col_org["컬럼명 (한글)"]))

df_bus_card_col_new_dict
# Out:
# {'on_date': '승차시각',
#  'off_date': '하차시각',
#  'route_name': '노선명',
#  'descr': '노선설명',
#  'age_type': '승객연령',
#  'trans_yn': '환승여부',
#  'addfee_yn': '추가운임여부',
#  'start_bstop': '승차정류장',
#  'start_gps_x': '승차정류장 GPS X',
#  'start_gps_y': '승차정류장 GPS Y',
#  'end_bstop': '하차정류장',
#  'end_gps_x': '하차정류장 GPS X',
#  'end_gps_y': '하차정류장 GPS Y'}

# %%
### 원본 데이터프레임의 컬럼명을 한글로 변환하기
df_bus_card_kor = df_bus_card_org.rename(columns = df_bus_card_col_new_dict)

# %%
df_bus_card_kor
# Out:
#                  승차시각            하차시각  노선명                   노선설명 승객연령 환승여부  \
# 0      20200102051049  20200102051844  131         양덕-송도-시청-양학-양덕   일반    N
# 1      20200102051338  20200102054549  175       문덕-고속터미널-선린병원-달전   일반    N
# 2      20200102051549  20200102051930  160         문덕-대송-송도-죽도-용흥   일반    N
# 3      20200102051617  20200102055046  175       문덕-고속터미널-선린병원-달전   일반    N
# 4      20200102051841  20200102052310  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    N
# ...               ...             ...  ...                    ...  ...  ...
# 16180  20200102232423  20200102233802  102  문덕-남구청-고속터미널-북구보건소-양덕   일반    Y
# 16181  20200102232449  20200102232657  200        양덕-남구청(야구장)-구룡포   일반    N
# 16182  20200102232849  20200102233230  500      문덕-시외터미널-흥해-청하-월포   일반    N
# 16183  20200102233518  20200102235624  107        문덕-시외(고속)터미널-흥해   일반    N
# 16184  20200102235936  20200103000017  108      양덕-죽도-양학-시청-유강-지곡   일반    N
#
#       추가운임여부   승차정류장  승차정류장 GPS X  승차정류장 GPS Y      하차정류장  하차정류장 GPS X  \
# 0          N   양덕차고지   129.401693    36.077258     동부초등학교   129.380866
# 1          N   문덕사거리   129.403178    35.962298  새마을금고해도지점   129.370626
# 2          N   문덕사거리   129.403442    35.962846    성우오토모티브   129.384492
# 3          N  부영사랑3차   129.402520    35.973038        오거리   129.366312
# 4          N    문덕온천   129.406532    35.961964      용덕사거리   129.415174
# ...      ...     ...          ...          ...        ...          ...
# 16180      N    죽도시장   129.365486    36.034110     문화예술회관   129.365551
# 16181      N   형산로터리   129.368470    36.011630  뱃머리 평생학습원   129.354538
# 16182      N   남부경찰서   129.344637    36.005408     연일전통시장   129.349210
# 16183      N   쌍용사거리   129.354637    36.015728      화이트빌라   129.406610
# 16184      N  장량휴먼시아   129.384057    36.090840      법원검찰청   129.387075
#
#        하차정류장 GPS Y
# 0        36.062209
# 1        36.015468
# 2        35.972675
# 3        36.031816
# 4        35.972826
# ...            ...
# 16180    36.010599
# 16181    36.009020
# 16182    35.997120
# 16183    35.957090
# 16184    36.090211
#
# [16185 rows x 13 columns]

# %%
df_bus_card_kor["승객연령"].unique()
# Out:
# array(['일반', '청소년', 'None', '어린이'], dtype=object)

# %% [markdown]
# ### 분석 주제들 정하기

# %%
### [버스 이용량 분석]
# 1. 기준월 및 기준일자별 버스 이용량 분석 비교
# 2. 기준일 및 기준시간대별 버스 이용량 분석 비교
# 3. 기준시간 및 시간(분)별 버스 이용량 분석 비교

### [버스 내 체류 시간]
# 1. 기준일 및 시간대별 버스내 체류시간(분) 분석비교
# 2. 시간대별 승객구분별 버스내 체류시간(분) 분석비교
# 3. 시간 및 승객구분별 빈도분석 비교

### [승하차정류장별 버스내 체류시간]
# 1. 승하차정류장별 버스내 체류시간(분) 상위 30건 비교분석

# %%
# ---- 2023.04.09 수업

# %%
df_bus_card_kor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16185 entries, 0 to 16184
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   승차시각         16185 non-null  int64
#  1   하차시각         16185 non-null  int64
#  2   노선명          16185 non-null  object
#  3   노선설명         16185 non-null  object
#  4   승객연령         16185 non-null  object
#  5   환승여부         16185 non-null  object
#  6   추가운임여부       16185 non-null  object
#  7   승차정류장        16185 non-null  object
#  8   승차정류장 GPS X  16185 non-null  float64
#  9   승차정류장 GPS Y  16185 non-null  float64
#  10  하차정류장        16185 non-null  object
#  11  하차정류장 GPS X  16185 non-null  float64
#  12  하차정류장 GPS Y  16185 non-null  float64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 1.6+ MB

# %%
### 승차시각 및 하차시각 타입변환하기 : 문자형태로...
df_bus_card_kor = df_bus_card_kor.astype({"승차시각" : "str"})
df_bus_card_kor = df_bus_card_kor.astype({"하차시각" : "str"})
df_bus_card_kor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16185 entries, 0 to 16184
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   승차시각         16185 non-null  object
#  1   하차시각         16185 non-null  object
#  2   노선명          16185 non-null  object
#  3   노선설명         16185 non-null  object
#  4   승객연령         16185 non-null  object
#  5   환승여부         16185 non-null  object
#  6   추가운임여부       16185 non-null  object
#  7   승차정류장        16185 non-null  object
#  8   승차정류장 GPS X  16185 non-null  float64
#  9   승차정류장 GPS Y  16185 non-null  float64
#  10  하차정류장        16185 non-null  object
#  11  하차정류장 GPS X  16185 non-null  float64
#  12  하차정류장 GPS Y  16185 non-null  float64
# dtypes: float64(4), object(9)
# memory usage: 1.6+ MB

# %%
### 분석에 필요한 요소(컬럼)을 별도 데이터프레임으로 추출하기
df_bus_cart = pd.DataFrame()

df_bus_cart["승차시각"] = pd.to_datetime(df_bus_card_kor["승차시각"])
df_bus_cart["하차시각"] = pd.to_datetime(df_bus_card_kor["하차시각"])
df_bus_cart["승객구분"] = df_bus_card_kor["승객연령"]
df_bus_cart["환승여부"] = df_bus_card_kor["환승여부"]
df_bus_cart["추가운임여부"] = df_bus_card_kor["추가운임여부"]
df_bus_cart["승차정류장"] = df_bus_card_kor["승차정류장"]
df_bus_cart["하차정류장"] = df_bus_card_kor["하차정류장"]


df_bus_cart
# Out:
#                      승차시각                하차시각 승객구분 환승여부 추가운임여부   승차정류장  \
# 0     2020-01-02 05:10:49 2020-01-02 05:18:44   일반    N      N   양덕차고지
# 1     2020-01-02 05:13:38 2020-01-02 05:45:49   일반    N      N   문덕사거리
# 2     2020-01-02 05:15:49 2020-01-02 05:19:30   일반    N      N   문덕사거리
# 3     2020-01-02 05:16:17 2020-01-02 05:50:46   일반    N      N  부영사랑3차
# 4     2020-01-02 05:18:41 2020-01-02 05:23:10   일반    N      N    문덕온천
# ...                   ...                 ...  ...  ...    ...     ...
# 16180 2020-01-02 23:24:23 2020-01-02 23:38:02   일반    Y      N    죽도시장
# 16181 2020-01-02 23:24:49 2020-01-02 23:26:57   일반    N      N   형산로터리
# 16182 2020-01-02 23:28:49 2020-01-02 23:32:30   일반    N      N   남부경찰서
# 16183 2020-01-02 23:35:18 2020-01-02 23:56:24   일반    N      N   쌍용사거리
# 16184 2020-01-02 23:59:36 2020-01-03 00:00:17   일반    N      N  장량휴먼시아
#
#            하차정류장
# 0         동부초등학교
# 1      새마을금고해도지점
# 2        성우오토모티브
# 3            오거리
# 4          용덕사거리
# ...          ...
# 16180     문화예술회관
# 16181  뱃머리 평생학습원
# 16182     연일전통시장
# 16183      화이트빌라
# 16184      법원검찰청
#
# [16185 rows x 7 columns]

# %%
###  체류시간 컬럼 생성하기
# - 체류시간 = 하차시각 - 승차시각
df_bus_cart_temp = df_bus_cart.copy()
df_bus_cart_temp["체류시간"] = df_bus_cart_temp["하차시각"] - df_bus_cart_temp["승차시각"]
df_bus_cart_temp
# Out:
#                      승차시각                하차시각 승객구분 환승여부 추가운임여부   승차정류장  \
# 0     2020-01-02 05:10:49 2020-01-02 05:18:44   일반    N      N   양덕차고지
# 1     2020-01-02 05:13:38 2020-01-02 05:45:49   일반    N      N   문덕사거리
# 2     2020-01-02 05:15:49 2020-01-02 05:19:30   일반    N      N   문덕사거리
# 3     2020-01-02 05:16:17 2020-01-02 05:50:46   일반    N      N  부영사랑3차
# 4     2020-01-02 05:18:41 2020-01-02 05:23:10   일반    N      N    문덕온천
# ...                   ...                 ...  ...  ...    ...     ...
# 16180 2020-01-02 23:24:23 2020-01-02 23:38:02   일반    Y      N    죽도시장
# 16181 2020-01-02 23:24:49 2020-01-02 23:26:57   일반    N      N   형산로터리
# 16182 2020-01-02 23:28:49 2020-01-02 23:32:30   일반    N      N   남부경찰서
# 16183 2020-01-02 23:35:18 2020-01-02 23:56:24   일반    N      N   쌍용사거리
# 16184 2020-01-02 23:59:36 2020-01-03 00:00:17   일반    N      N  장량휴먼시아
#
#            하차정류장            체류시간
# 0         동부초등학교 0 days 00:07:55
# 1      새마을금고해도지점 0 days 00:32:11
# 2        성우오토모티브 0 days 00:03:41
# 3            오거리 0 days 00:34:29
# 4          용덕사거리 0 days 00:04:29
# ...          ...             ...
# 16180     문화예술회관 0 days 00:13:39
# 16181  뱃머리 평생학습원 0 days 00:02:08
# 16182     연일전통시장 0 days 00:03:41
# 16183      화이트빌라 0 days 00:21:06
# 16184      법원검찰청 0 days 00:00:41
#
# [16185 rows x 8 columns]

# %%
df_bus_cart_temp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16185 entries, 0 to 16184
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   승차시각    16185 non-null  datetime64[ns]
#  1   하차시각    16185 non-null  datetime64[ns]
#  2   승객구분    16185 non-null  object
#  3   환승여부    16185 non-null  object
#  4   추가운임여부  16185 non-null  object
#  5   승차정류장   16185 non-null  object
#  6   하차정류장   16185 non-null  object
#  7   체류시간    16185 non-null  timedelta64[ns]
# dtypes: datetime64[ns](2), object(5), timedelta64[ns](1)
# memory usage: 1011.7+ KB

# %%
df_bus_cart_temp["체류시간"] = (df_bus_cart_temp["하차시각"] - df_bus_cart_temp["승차시각"]).astype("timedelta64[m]")
df_bus_cart_temp
# Out:
#                      승차시각                하차시각 승객구분 환승여부 추가운임여부   승차정류장  \
# 0     2020-01-02 05:10:49 2020-01-02 05:18:44   일반    N      N   양덕차고지
# 1     2020-01-02 05:13:38 2020-01-02 05:45:49   일반    N      N   문덕사거리
# 2     2020-01-02 05:15:49 2020-01-02 05:19:30   일반    N      N   문덕사거리
# 3     2020-01-02 05:16:17 2020-01-02 05:50:46   일반    N      N  부영사랑3차
# 4     2020-01-02 05:18:41 2020-01-02 05:23:10   일반    N      N    문덕온천
# ...                   ...                 ...  ...  ...    ...     ...
# 16180 2020-01-02 23:24:23 2020-01-02 23:38:02   일반    Y      N    죽도시장
# 16181 2020-01-02 23:24:49 2020-01-02 23:26:57   일반    N      N   형산로터리
# 16182 2020-01-02 23:28:49 2020-01-02 23:32:30   일반    N      N   남부경찰서
# 16183 2020-01-02 23:35:18 2020-01-02 23:56:24   일반    N      N   쌍용사거리
# 16184 2020-01-02 23:59:36 2020-01-03 00:00:17   일반    N      N  장량휴먼시아
#
#            하차정류장  체류시간
# 0         동부초등학교   7.0
# 1      새마을금고해도지점  32.0
# 2        성우오토모티브   3.0
# 3            오거리  34.0
# 4          용덕사거리   4.0
# ...          ...   ...
# 16180     문화예술회관  13.0
# 16181  뱃머리 평생학습원   2.0
# 16182     연일전통시장   3.0
# 16183      화이트빌라  21.0
# 16184      법원검찰청   0.0
#
# [16185 rows x 8 columns]

# %%
df_bus_cart_temp["체류시간"] = (df_bus_cart_temp["하차시각"] - df_bus_cart_temp["승차시각"]).astype("timedelta64[m]").astype("int")
df_bus_cart_temp
# Out:
#                      승차시각                하차시각 승객구분 환승여부 추가운임여부   승차정류장  \
# 0     2020-01-02 05:10:49 2020-01-02 05:18:44   일반    N      N   양덕차고지
# 1     2020-01-02 05:13:38 2020-01-02 05:45:49   일반    N      N   문덕사거리
# 2     2020-01-02 05:15:49 2020-01-02 05:19:30   일반    N      N   문덕사거리
# 3     2020-01-02 05:16:17 2020-01-02 05:50:46   일반    N      N  부영사랑3차
# 4     2020-01-02 05:18:41 2020-01-02 05:23:10   일반    N      N    문덕온천
# ...                   ...                 ...  ...  ...    ...     ...
# 16180 2020-01-02 23:24:23 2020-01-02 23:38:02   일반    Y      N    죽도시장
# 16181 2020-01-02 23:24:49 2020-01-02 23:26:57   일반    N      N   형산로터리
# 16182 2020-01-02 23:28:49 2020-01-02 23:32:30   일반    N      N   남부경찰서
# 16183 2020-01-02 23:35:18 2020-01-02 23:56:24   일반    N      N   쌍용사거리
# 16184 2020-01-02 23:59:36 2020-01-03 00:00:17   일반    N      N  장량휴먼시아
#
#            하차정류장  체류시간
# 0         동부초등학교     7
# 1      새마을금고해도지점    32
# 2        성우오토모티브     3
# 3            오거리    34
# 4          용덕사거리     4
# ...          ...   ...
# 16180     문화예술회관    13
# 16181  뱃머리 평생학습원     2
# 16182     연일전통시장     3
# 16183      화이트빌라    21
# 16184      법원검찰청     0
#
# [16185 rows x 8 columns]

# %%
df_bus_cart["버스내체류시간(분)"] = (df_bus_cart["하차시각"] - df_bus_cart["승차시각"]).astype("timedelta64[m]").astype("int")
df_bus_cart.info()
df_bus_cart.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16185 entries, 0 to 16184
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   승차시각        16185 non-null  datetime64[ns]
#  1   하차시각        16185 non-null  datetime64[ns]
#  2   승객구분        16185 non-null  object
#  3   환승여부        16185 non-null  object
#  4   추가운임여부      16185 non-null  object
#  5   승차정류장       16185 non-null  object
#  6   하차정류장       16185 non-null  object
#  7   버스내체류시간(분)  16185 non-null  int32
# dtypes: datetime64[ns](2), int32(1), object(5)
# memory usage: 948.5+ KB
#          버스내체류시간(분)
# count  16185.000000
# mean      16.345505
# std       12.365620
# min        0.000000
# 25%        7.000000
# 50%       13.000000
# 75%       22.000000
# max       89.000000

# %%
### 기준년도, 기준월, 기준일, 기준시간, 기준시간(분) 컬럼생성
df_bus_cart["기준년도"] = df_bus_cart["승차시각"].dt.year
df_bus_cart["기준월"] = df_bus_cart["승차시각"].dt.month
df_bus_cart["기준일"] = df_bus_cart["승차시각"].dt.day
df_bus_cart["기준시간"] = df_bus_cart["승차시각"].dt.hour
df_bus_cart["기준시간(분)"] = df_bus_cart["승차시각"].dt.minute
df_bus_cart
# Out:
#                      승차시각                하차시각 승객구분 환승여부 추가운임여부   승차정류장  \
# 0     2020-01-02 05:10:49 2020-01-02 05:18:44   일반    N      N   양덕차고지
# 1     2020-01-02 05:13:38 2020-01-02 05:45:49   일반    N      N   문덕사거리
# 2     2020-01-02 05:15:49 2020-01-02 05:19:30   일반    N      N   문덕사거리
# 3     2020-01-02 05:16:17 2020-01-02 05:50:46   일반    N      N  부영사랑3차
# 4     2020-01-02 05:18:41 2020-01-02 05:23:10   일반    N      N    문덕온천
# ...                   ...                 ...  ...  ...    ...     ...
# 16180 2020-01-02 23:24:23 2020-01-02 23:38:02   일반    Y      N    죽도시장
# 16181 2020-01-02 23:24:49 2020-01-02 23:26:57   일반    N      N   형산로터리
# 16182 2020-01-02 23:28:49 2020-01-02 23:32:30   일반    N      N   남부경찰서
# 16183 2020-01-02 23:35:18 2020-01-02 23:56:24   일반    N      N   쌍용사거리
# 16184 2020-01-02 23:59:36 2020-01-03 00:00:17   일반    N      N  장량휴먼시아
#
#            하차정류장  버스내체류시간(분)  기준년도  기준월  기준일  기준시간  기준시간(분)
# 0         동부초등학교           7  2020    1    2     5       10
# 1      새마을금고해도지점          32  2020    1    2     5       13
# 2        성우오토모티브           3  2020    1    2     5       15
# 3            오거리          34  2020    1    2     5       16
# 4          용덕사거리           4  2020    1    2     5       18
# ...          ...         ...   ...  ...  ...   ...      ...
# 16180     문화예술회관          13  2020    1    2    23       24
# 16181  뱃머리 평생학습원           2  2020    1    2    23       24
# 16182     연일전통시장           3  2020    1    2    23       28
# 16183      화이트빌라          21  2020    1    2    23       35
# 16184      법원검찰청           0  2020    1    2    23       59
#
# [16185 rows x 13 columns]

# %%
df_bus_cart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16185 entries, 0 to 16184
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   승차시각        16185 non-null  datetime64[ns]
#  1   하차시각        16185 non-null  datetime64[ns]
#  2   승객구분        16185 non-null  object
#  3   환승여부        16185 non-null  object
#  4   추가운임여부      16185 non-null  object
#  5   승차정류장       16185 non-null  object
#  6   하차정류장       16185 non-null  object
#  7   버스내체류시간(분)  16185 non-null  int32
#  8   기준년도        16185 non-null  int64
#  9   기준월         16185 non-null  int64
#  10  기준일         16185 non-null  int64
#  11  기준시간        16185 non-null  int64
#  12  기준시간(분)     16185 non-null  int64
# dtypes: datetime64[ns](2), int32(1), int64(5), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# ### 모든 데이터 통합하기

# %%
from datetime import datetime

# %%
### 실행시간 체크하기
# - 시작시간
start_date = datetime.today().strftime("%Y-%m-%d %H:%M:%S")


### 최종 통합 데이터를 저장할 데이터프레임
df_bus_card_tot = pd.DataFrame()

### 아래 데이터 통합 프로그래밍 하기
for i in range(0, 80, 1) : 
    
    ### 1.파일 읽어들이기
    file_path = "./01_data_원본/trfcard ({})/trfcard.csv".format(i)    
    df_bus_card_org = pd.read_csv(file_path)
    
    
    file_path = "./01_data_원본/trfcard ({})/trfcard_columns.xlsx".format(i)    
    df_bus_card_col_org = pd.read_excel(file_path, 
                                        header = 2, 
                                        usecols = "B:C")
    
    ### 영문 컬럼명을 한글로 변환하기 
    ### 딕셔너리 만들기 - 1방식
    df_bus_card_col_new_dict = {}
    for k, v in zip(df_bus_card_col_org["컬럼명 (영문)"],
                    df_bus_card_col_org["컬럼명 (한글)"]) :
        df_bus_card_col_new_dict[k] = v 

    
    ### 원본 데이터프레임의 컬럼명을 한글로 변환하기
    df_bus_card_kor = df_bus_card_org.rename(columns = df_bus_card_col_new_dict)
    
    ### 체류시간(분) 컬럼 추가하기
    ### 승차시각 및 하차시각 타입변환하기 : 문자형태로...
    df_bus_card_kor = df_bus_card_kor.astype({"승차시각" : "str"})
    df_bus_card_kor = df_bus_card_kor.astype({"하차시각" : "str"})
    
    
    ### 분석에 필요한 요소(컬럼)을 별도 데이터프레임으로 추출하기
    df_bus_cart = pd.DataFrame()

    df_bus_cart["승차시각"] = pd.to_datetime(df_bus_card_kor["승차시각"])
    df_bus_cart["하차시각"] = pd.to_datetime(df_bus_card_kor["하차시각"])
    df_bus_cart["승객구분"] = df_bus_card_kor["승객연령"]
    df_bus_cart["환승여부"] = df_bus_card_kor["환승여부"]
    df_bus_cart["추가운임여부"] = df_bus_card_kor["추가운임여부"]
    df_bus_cart["승차정류장"] = df_bus_card_kor["승차정류장"]
    df_bus_cart["하차정류장"] = df_bus_card_kor["하차정류장"]

    df_bus_cart["버스내체류시간(분)"] = (df_bus_cart["하차시각"] - df_bus_cart["승차시각"]).astype("timedelta64[m]").astype("int")

    ### 기준년도, 기준월, 기준일, 기준시간, 기준시간(분) 컬럼생성
    df_bus_cart["기준년도"] = df_bus_cart["승차시각"].dt.year
    df_bus_cart["기준월"] = df_bus_cart["승차시각"].dt.month
    df_bus_cart["기준일"] = df_bus_cart["승차시각"].dt.day
    df_bus_cart["기준시간"] = df_bus_cart["승차시각"].dt.hour
    df_bus_cart["기준시간(분)"] = df_bus_cart["승차시각"].dt.minute 
    
    # 통합하기
    # - ignore_index = True : 기존의 인덱스 번호에 이어서 자동 증가시키기
    df_bus_card_tot = pd.concat([df_bus_card_tot, df_bus_cart], ignore_index = True)
    
    
# - 종료시간
end_date = datetime.today().strftime("%Y-%m-%d %H:%M:%S")

print("전체 시작~종료 시간 = ({}) ~ ({})".format(start_date, end_date))
print("전체 데이터 행수 - ", len(df_bus_card_tot))

df_bus_card_tot
# Out:
# 전체 시작~종료 시간 = (2023-04-09 11:06:55) ~ (2023-04-09 11:07:37)
# 전체 데이터 행수 -  842608
#                       승차시각                하차시각 승객구분 환승여부 추가운임여부    승차정류장  \
# 0      2020-01-02 05:10:49 2020-01-02 05:18:44   일반    N      N    양덕차고지
# 1      2020-01-02 05:13:38 2020-01-02 05:45:49   일반    N      N    문덕사거리
# 2      2020-01-02 05:15:49 2020-01-02 05:19:30   일반    N      N    문덕사거리
# 3      2020-01-02 05:16:17 2020-01-02 05:50:46   일반    N      N   부영사랑3차
# 4      2020-01-02 05:18:41 2020-01-02 05:23:10   일반    N      N     문덕온천
# ...                    ...                 ...  ...  ...    ...      ...
# 842603 2020-03-31 23:15:29 2020-03-31 23:20:33   일반    N      N    법원사거리
# 842604 2020-03-31 23:16:51 2020-03-31 23:20:54   일반    N      N   LG빌라입구
# 842605 2020-03-31 23:38:06 2020-03-31 23:45:46   일반    N      N  대동우방아파트
# 842606 2020-03-31 23:48:33 2020-03-31 23:59:54   일반    N      N    해병대서문
# 842607 2020-03-31 23:56:43 2020-04-01 00:04:08   일반    N      N    해병대서문
#
#             하차정류장  버스내체류시간(분)  기준년도  기준월  기준일  기준시간  기준시간(분)
# 0          동부초등학교           7  2020    1    2     5       10
# 1       새마을금고해도지점          32  2020    1    2     5       13
# 2         성우오토모티브           3  2020    1    2     5       15
# 3             오거리          34  2020    1    2     5       16
# 4           용덕사거리           4  2020    1    2     5       18
# ...           ...         ...   ...  ...  ...   ...      ...
# 842603    농협하나로클럽           5  2020    3   31    23       15
# 842604    대잠중앙하이츠           4  2020    3   31    23       16
# 842605       상대시장           7  2020    3   31    23       38
# 842606     부영사랑3차          11  2020    3   31    23       48
# 842607      문덕사거리           7  2020    3   31    23       56
#
# [842608 rows x 13 columns]

# %%
### 통합본 파일로 저장하기
df_bus_card_tot.to_csv("./02_data_통합본/df_bus_tot.csv", index = None)
